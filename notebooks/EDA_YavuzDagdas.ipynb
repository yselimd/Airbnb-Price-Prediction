# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import math

# %%
listings = pd.read_csv('../data/listings_clean.csv')

# %%
# converting data type to datetime.
listings[['host_since', 'calendar_last_scraped','first_review','last_review']] = listings[['host_since', 'calendar_last_scraped','first_review','last_review']].apply(pd.to_datetime)

# %%
# changing data type of is,host_id columns to object
listings[['id','host_id']] = listings[['id','host_id']].astype('object')

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6883 entries, 0 to 6882
# Data columns (total 57 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            6883 non-null   object
#  1   host_id                                       6883 non-null   object
#  2   host_since                                    6868 non-null   datetime64[ns]
#  3   host_response_time                            5021 non-null   object
#  4   host_response_rate                            5021 non-null   float64
#  5   host_acceptance_rate                          5517 non-null   float64
#  6   host_is_superhost                             6868 non-null   float64
#  7   host_listings_count                           6868 non-null   float64
#  8   host_total_listings_count                     6868 non-null   float64
#  9   host_verifications                            6883 non-null   object
#  10  host_has_profile_pic                          6868 non-null   float64
#  11  host_identity_verified                        6868 non-null   float64
#  12  neighbourhood                                 4938 non-null   object
#  13  neighbourhood_cleansed                        6883 non-null   object
#  14  latitude                                      6883 non-null   float64
#  15  longitude                                     6883 non-null   float64
#  16  property_type                                 6883 non-null   object
#  17  room_type                                     6883 non-null   object
#  18  accommodates                                  6883 non-null   int64
#  19  bathrooms                                     6878 non-null   float64
#  20  bedrooms                                      6883 non-null   float64
#  21  beds                                          6883 non-null   float64
#  22  amenities                                     6883 non-null   object
#  23  price                                         6883 non-null   float64
#  24  minimum_nights                                6883 non-null   int64
#  25  maximum_nights                                6883 non-null   int64
#  26  minimum_minimum_nights                        6883 non-null   int64
#  27  maximum_minimum_nights                        6883 non-null   int64
#  28  minimum_maximum_nights                        6883 non-null   int64
#  29  maximum_maximum_nights                        6883 non-null   int64
#  30  minimum_nights_avg_ntm                        6883 non-null   float64
#  31  maximum_nights_avg_ntm                        6883 non-null   float64
#  32  has_availability                              6883 non-null   int64
#  33  availability_30                               6883 non-null   int64
#  34  availability_60                               6883 non-null   int64
#  35  availability_90                               6883 non-null   int64
#  36  availability_365                              6883 non-null   int64
#  37  calendar_last_scraped                         6883 non-null   datetime64[ns]
#  38  number_of_reviews                             6883 non-null   int64
#  39  number_of_reviews_ltm                         6883 non-null   int64
#  40  number_of_reviews_l30d                        6883 non-null   int64
#  41  first_review                                  5189 non-null   datetime64[ns]
#  42  last_review                                   5189 non-null   datetime64[ns]
#  43  review_scores_rating                          5148 non-null   float64
#  44  review_scores_accuracy                        5125 non-null   float64
#  45  review_scores_cleanliness                     5125 non-null   float64
#  46  review_scores_checkin                         5124 non-null   float64
#  47  review_scores_communication                   5126 non-null   float64
#  48  review_scores_location                        5124 non-null   float64
#  49  review_scores_value                           5124 non-null   float64
#  50  license                                       3878 non-null   object
#  51  instant_bookable                              6883 non-null   int64
#  52  calculated_host_listings_count                6883 non-null   int64
#  53  calculated_host_listings_count_entire_homes   6883 non-null   int64
#  54  calculated_host_listings_count_private_rooms  6883 non-null   int64
#  55  calculated_host_listings_count_shared_rooms   6883 non-null   int64
#  56  reviews_per_month                             5189 non-null   float64
# dtypes: datetime64[ns](4), float64(23), int64(20), object(10)
# memory usage: 3.0+ MB

# %%
# plotting the distribution of the variables in the listings data frame.

listings.hist(figsize=(40,40))
plt.subplots_adjust(hspace=0.5);

# %% [markdown]
# * Histograms reveal that small portion of hosts own large number of listings and majority own single listing.
# * host_listings_count and host_total_listings_count has a very similar distribution, I will check if they have same values or if they are highly correlated. If so I will drop one of the variables.
# * Looks like we have a similar situation for the calculted_host_listings_count and calculted_host_listings_count .

# %%
# Creating a features dataframe by selecting columns which has data type float64 and int64.

features = listings.select_dtypes(include=['float64','int64'])
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6883 entries, 0 to 6882
# Data columns (total 43 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   host_response_rate                            5021 non-null   float64
#  1   host_acceptance_rate                          5517 non-null   float64
#  2   host_is_superhost                             6868 non-null   float64
#  3   host_listings_count                           6868 non-null   float64
#  4   host_total_listings_count                     6868 non-null   float64
#  5   host_has_profile_pic                          6868 non-null   float64
#  6   host_identity_verified                        6868 non-null   float64
#  7   latitude                                      6883 non-null   float64
#  8   longitude                                     6883 non-null   float64
#  9   accommodates                                  6883 non-null   int64
#  10  bathrooms                                     6878 non-null   float64
#  11  bedrooms                                      6883 non-null   float64
#  12  beds                                          6883 non-null   float64
#  13  price                                         6883 non-null   float64
#  14  minimum_nights                                6883 non-null   int64
#  15  maximum_nights                                6883 non-null   int64
#  16  minimum_minimum_nights                        6883 non-null   int64
#  17  maximum_minimum_nights                        6883 non-null   int64
#  18  minimum_maximum_nights                        6883 non-null   int64
#  19  maximum_maximum_nights                        6883 non-null   int64
#  20  minimum_nights_avg_ntm                        6883 non-null   float64
#  21  maximum_nights_avg_ntm                        6883 non-null   float64
#  22  has_availability                              6883 non-null   int64
#  23  availability_30                               6883 non-null   int64
#  24  availability_60                               6883 non-null   int64
#  25  availability_90                               6883 non-null   int64
#  26  availability_365                              6883 non-null   int64
#  27  number_of_reviews                             6883 non-null   int64
#  28  number_of_reviews_ltm                         6883 non-null   int64
#  29  number_of_reviews_l30d                        6883 non-null   int64
#  30  review_scores_rating                          5148 non-null   float64
#  31  review_scores_accuracy                        5125 non-null   float64
#  32  review_scores_cleanliness                     5125 non-null   float64
#  33  review_scores_checkin                         5124 non-null   float64
#  34  review_scores_communication                   5126 non-null   float64
#  35  review_scores_location                        5124 non-null   float64
#  36  review_scores_value                           5124 non-null   float64
#  37  instant_bookable                              6883 non-null   int64
#  38  calculated_host_listings_count                6883 non-null   int64
#  39  calculated_host_listings_count_entire_homes   6883 non-null   int64
#  40  calculated_host_listings_count_private_rooms  6883 non-null   int64
#  41  calculated_host_listings_count_shared_rooms   6883 non-null   int64
#  42  reviews_per_month                             5189 non-null   float64
# dtypes: float64(23), int64(20)
# memory usage: 2.3 MB

# %%
listings['beds'].sort_values(ascending=False)
# Out:
# 6159    14.0
# 3615    12.0
# 1444    12.0
# 3008    10.0
# 6075    10.0
#         ...
# 3010     1.0
# 3009     1.0
# 3007     1.0
# 3006     1.0
# 6882     1.0
# Name: beds, Length: 6883, dtype: float64

# %% [markdown]
# * I would assume that number of beds, number of bedrooms and number of people a listing can accomodate would have an association with the price column.

# %%
# define useful function to create scatterplots of ticket prices against desired columns
def scatterplots(columns, ncol=None, figsize=(15, 8)):
    if ncol is None:
        ncol = len(columns)
    nrow = int(np.ceil(len(columns) / ncol))
    fig, axes = plt.subplots(nrow, ncol, figsize=figsize, squeeze=False)
    fig.subplots_adjust(wspace=0.5, hspace=0.6)
    for i, col in enumerate(columns):
        ax = axes.flatten()[i]
        ax.scatter(x =col, y = 'price', alpha=0.5,data=features)
        ax.set(xlabel=col, ylabel='price')
    nsubplots = nrow * ncol   
    for empty in range(i+1, nsubplots):
        axes.flatten()[empty].set_visible(False)

# %%
scatterplots(features.columns, ncol=4,figsize=(20,40))

# %% [markdown]
# * Since these variables are not continous values and they are mostly discrete it is not possible to see an association using the scatter plot. I will repeat the visualization with the boxplot.

# %%
# assigning column names of interest into cols list.
cols = ['room_type','accommodates','bathrooms','bedrooms','beds','neighbourhood_cleansed']

# plotting barplot to visualize number of subgroups in each column i.e. room_types and price 
# plotting boxplot to visualize subgroups in each column vs the price.

nrow=len(cols)
fig, axs = plt.subplots(nrow,2,figsize=(30,60))
#fig.subplots_adjust(wspace=0.5, hspace=0.6)
for i in range(nrow):
    plt.subplot(nrow,2,2*i+1)
    listings[cols[i]].value_counts().plot(kind='barh')
    plt.ylabel(cols[i])
    plt.xlabel('Number of listings')
    plt.subplot(nrow,2,2*i+2)
    sns.boxplot(x=cols[i], y=np.log10(listings.price), data=listings)
    plt.ylabel('price')
    plt.xlabel(cols[i])
    plt.xticks(rotation=60)

# %% [markdown]
# * Majority of listings are Entire home or apartments. The price distribution of each listing type reveals that hotel rooms tend to be most expensive followed by entire home/apartments. Least expensive listings are shared rooms.
#
# * There is a possitive trend between price of the listings and number of bedrooms, number of beds and number of people a listing can accomodate.
#
# * Price distribution is similar across the neighbourhoods.

# %%
plt.figure(figsize=(20, 15))
sns.heatmap(listings.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# * The heatmap reveals that several attributes are highly correlated with each other, i.e. calculated_host_listings_count,total_listings_count. I will need to drop some of these attributes to avoid collinearity.

# %%
calendar = pd.read_csv('../data/calendar_clean.csv')

# %%
# Changing data type of date column to datetime
calendar['date'] = pd.to_datetime(calendar['date'])

# %%
calendar.head()
# Out:
#    listing_id       date  available  price  adjusted_price  minimum_nights  \
# 0         958 2021-03-02          0  130.0           130.0               2
# 1       53280 2021-03-02          0   95.0            95.0               3
# 2       53280 2021-03-03          0   95.0            95.0               3
# 3       53280 2021-03-04          0   95.0            95.0               3
# 4       53280 2021-03-05          0   95.0            95.0               3
#
#    maximum_nights
# 0            1125
# 1              60
# 2              60
# 3              60
# 4              60

# %%
calendar['price_difference']=calendar['adjusted_price']-calendar['price']
calendar['weekday'] = pd.Series(calendar.date).dt.dayofweek

# %%
df=calendar.groupby('date')[['price']].mean().reset_index()

# %%
df2=calendar.groupby('date')[['price']].median().reset_index()

# %%
plt.plot(df.date,df.price)
plt.plot(df2.date,df2.price)
plt.xlim()
# Out:
# (18668.7, 19071.3)
